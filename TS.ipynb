# %% [markdown]
# <a href="https://colab.research.google.com/github/Nabanita29/Research/blob/main/TS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Number of buttons (arms)
num_buttons = 2

# True reward probabilities for each button (unknown to the robot)
true_probabilities = np.random.uniform(0.1, 0.9, num_buttons)

# Number of rounds to interact with the environment
num_rounds = 100

# Initialize variables to keep track of successes and failures for each button
successes = np.zeros(num_buttons)
failures = np.zeros(num_buttons)



# Initialize variables to store cumulative rewards and chosen actions
cumulative_rewards = []
chosen_actions = []

# Thompson Sampling algorithm for the baby robot
for _ in range(num_rounds):
    sampled_values = np.random.beta(successes + 1, failures + 1)  # Sample from Beta distribution
    chosen_button = np.argmax(sampled_values)  # Choose button with the highest sampled value
    reward = np.random.binomial(1, true_probabilities[chosen_button])  # Simulate reward from chosen button
    if reward == 1:
        successes[chosen_button] += 1
    else:
        failures[chosen_button] += 1
    cumulative_rewards.append(reward)
    chosen_actions.append(chosen_button)

# Calculate cumulative rewards
cumulative_rewards = np.cumsum(cumulative_rewards)

# Print cumulative rewards and chosen actions
for t in range(num_rounds):
    print(f"Round {t + 1}: Chose Button {chosen_actions[t]}, Cumulative Reward: {cumulative_rewards[t]}")

# Plot cumulative rewards over time (optional, requires matplotlib)
import matplotlib.pyplot as plt

plt.plot(cumulative_rewards)
plt.xlabel("Round")
plt.ylabel("Cumulative Reward")
plt.title("Cumulative Reward Over Time (Thompson Sampling for Baby Robot)")
plt.show()
# Out:
# Round 1: Chose Button 1, Cumulative Reward: 0
# Round 2: Chose Button 1, Cumulative Reward: 0
# Round 3: Chose Button 1, Cumulative Reward: 0
# Round 4: Chose Button 0, Cumulative Reward: 1
# Round 5: Chose Button 0, Cumulative Reward: 1
# Round 6: Chose Button 0, Cumulative Reward: 2
# Round 7: Chose Button 0, Cumulative Reward: 3
# Round 8: Chose Button 0, Cumulative Reward: 3
# Round 9: Chose Button 0, Cumulative Reward: 3
# Round 10: Chose Button 0, Cumulative Reward: 4
# Round 11: Chose Button 0, Cumulative Reward: 5
# Round 12: Chose Button 0, Cumulative Reward: 6
# Round 13: Chose Button 0, Cumulative Reward: 7
# Round 14: Chose Button 0, Cumulative Reward: 7
# Round 15: Chose Button 0, Cumulative Reward: 7
# Round 16: Chose Button 0, Cumulative Reward: 7
# Round 17: Chose Button 0, Cumulative Reward: 7
# Round 18: Chose Button 0, Cumulative Reward: 8
# Round 19: Chose Button 0, Cumulative Reward: 8
# Round 20: Chose Button 0, Cumulative Reward: 8
# Round 21: Chose Button 0, Cumulative Reward: 8
# Round 22: Chose Button 0, Cumulative Reward: 9
# Round 23: Chose Button 0, Cumulative Reward: 9
# Round 24: Chose Button 0, Cumulative Reward: 9
# Round 25: Chose Button 0, Cumulative Reward: 9
# Round 26: Chose Button 0, Cumulative Reward: 9
# Round 27: Chose Button 0, Cumulative Reward: 9
# Round 28: Chose Button 1, Cumulative Reward: 10
# Round 29: Chose Button 1, Cumulative Reward: 11
# Round 30: Chose Button 1, Cumulative Reward: 11
# Round 31: Chose Button 0, Cumulative Reward: 12
# Round 32: Chose Button 0, Cumulative Reward: 12
# Round 33: Chose Button 0, Cumulative Reward: 12
# Round 34: Chose Button 1, Cumulative Reward: 12
# Round 35: Chose Button 0, Cumulative Reward: 12
# Round 36: Chose Button 1, Cumulative Reward: 12
# Round 37: Chose Button 0, Cumulative Reward: 13
# Round 38: Chose Button 0, Cumulative Reward: 13
# Round 39: Chose Button 1, Cumulative Reward: 13
# Round 40: Chose Button 0, Cumulative Reward: 13
# Round 41: Chose Button 0, Cumulative Reward: 13
# Round 42: Chose Button 1, Cumulative Reward: 13
# Round 43: Chose Button 0, Cumulative Reward: 13
# Round 44: Chose Button 1, Cumulative Reward: 13
# Round 45: Chose Button 1, Cumulative Reward: 14
# Round 46: Chose Button 0, Cumulative Reward: 15
# Round 47: Chose Button 0, Cumulative Reward: 16
# Round 48: Chose Button 0, Cumulative Reward: 16
# Round 49: Chose Button 0, Cumulative Reward: 17
# Round 50: Chose Button 1, Cumulative Reward: 17
# Round 51: Chose Button 1, Cumulative Reward: 17
# Round 52: Chose Button 0, Cumulative Reward: 18
# Round 53: Chose Button 1, Cumulative Reward: 19
# Round 54: Chose Button 0, Cumulative Reward: 20
# Round 55: Chose Button 0, Cumulative Reward: 20
# Round 56: Chose Button 0, Cumulative Reward: 21
# Round 57: Chose Button 0, Cumulative Reward: 22
# Round 58: Chose Button 0, Cumulative Reward: 22
# Round 59: Chose Button 1, Cumulative Reward: 22
# Round 60: Chose Button 0, Cumulative Reward: 22
# Round 61: Chose Button 0, Cumulative Reward: 22
# Round 62: Chose Button 0, Cumulative Reward: 22
# Round 63: Chose Button 0, Cumulative Reward: 22
# Round 64: Chose Button 0, Cumulative Reward: 22
# Round 65: Chose Button 0, Cumulative Reward: 23
# Round 66: Chose Button 0, Cumulative Reward: 24
# Round 67: Chose Button 0, Cumulative Reward: 24
# Round 68: Chose Button 0, Cumulative Reward: 25
# Round 69: Chose Button 0, Cumulative Reward: 25
# Round 70: Chose Button 0, Cumulative Reward: 25
# Round 71: Chose Button 1, Cumulative Reward: 25
# Round 72: Chose Button 0, Cumulative Reward: 25
# Round 73: Chose Button 0, Cumulative Reward: 25
# Round 74: Chose Button 0, Cumulative Reward: 25
# Round 75: Chose Button 0, Cumulative Reward: 26
# Round 76: Chose Button 0, Cumulative Reward: 26
# Round 77: Chose Button 0, Cumulative Reward: 27
# Round 78: Chose Button 0, Cumulative Reward: 28
# Round 79: Chose Button 1, Cumulative Reward: 28
# Round 80: Chose Button 1, Cumulative Reward: 28
# Round 81: Chose Button 0, Cumulative Reward: 29
# Round 82: Chose Button 0, Cumulative Reward: 30
# Round 83: Chose Button 1, Cumulative Reward: 30
# Round 84: Chose Button 0, Cumulative Reward: 30
# Round 85: Chose Button 0, Cumulative Reward: 31
# Round 86: Chose Button 0, Cumulative Reward: 32
# Round 87: Chose Button 0, Cumulative Reward: 33
# Round 88: Chose Button 0, Cumulative Reward: 34
# Round 89: Chose Button 0, Cumulative Reward: 34
# Round 90: Chose Button 0, Cumulative Reward: 35
# Round 91: Chose Button 0, Cumulative Reward: 35
# Round 92: Chose Button 0, Cumulative Reward: 36
# Round 93: Chose Button 1, Cumulative Reward: 36
# Round 94: Chose Button 0, Cumulative Reward: 36
# Round 95: Chose Button 0, Cumulative Reward: 36
# Round 96: Chose Button 0, Cumulative Reward: 36
# Round 97: Chose Button 0, Cumulative Reward: 37
# Round 98: Chose Button 1, Cumulative Reward: 37
# Round 99: Chose Button 0, Cumulative Reward: 38
# Round 100: Chose Button 0, Cumulative Reward: 38
